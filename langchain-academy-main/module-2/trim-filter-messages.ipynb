# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-2/trim-filter-messages.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239435-lesson-4-trim-and-filter-messages)

# %% [markdown]
# # Filtering and trimming messages
#
# ## Review
#
# Now, we have a deeper understanding of a few things:
#
# * How to customize the graph state schema
# * How to define custom state reducers
# * How to use multiple graph state schemas
#
# ## Goals
#
# Now, we can start using these concepts with models in LangGraph!
#
# In the next few sessions, we'll build towards a chatbot that has long-term memory.
#
# Because our chatbot will use messages, let's first talk a bit more about advanced ways to work with messages in graph state.

# %%
# !pip install --quiet -U langchain_core langgraph langchain_groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 2.8 MB/s eta 0:00:00

# %%
from google.colab import userdata
import os

os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')

# %% [markdown]
# We'll use [LangSmith](https://docs.smith.langchain.com/) for [tracing](https://docs.smith.langchain.com/concepts/tracing).
#
# We'll log to a project, `langchain-academy`.

# %%
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_ENDPOINT"]="https://api.smith.langchain.com"
os.environ["LANGCHAIN_API_KEY"]=userdata.get('LANGCHAIN_API_KEY')
os.environ["LANGCHAIN_PROJECT"]="langchain_tutorials"

# %% [markdown]
# ## Messages as state
#
# First, let's define some messages.

# %%
from pprint import pprint
from langchain_core.messages import AIMessage, HumanMessage
messages = [AIMessage(f"So you said you were researching ocean mammals?", name="Bot")]
messages.append(HumanMessage(f"Yes, I know about whales. But what others should I learn about?", name="Lance"))

for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?

# %% [markdown]
# Recall we can pass them to a chat model.

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="llama3-8b-8192")
llm.invoke(messages)
# Out:
# AIMessage(content='There are many fascinating ocean mammals beyond whales! Here are some you might want to explore:\n\n1. **Dolphins**: These intelligent, social creatures are known for their playful behavior and ability to communicate with each other using clicks and whistles.\n2. **Seals and sea lions**: These fin-footed mammals are adapted to life in the ocean, with flippers instead of limbs. They\'re excellent swimmers and can haul themselves out of the water to rest.\n3. **Manatees**: Also known as "sea cows," manatees are large, slow-moving aquatic mammals that inhabit shallow waters in the Caribbean and Gulf of Mexico.\n4. **Walruses**: These large, tusked mammals are found in Arctic and sub-Arctic waters. They use their tusks to dig for clams and other marine animals.\n5. **Monk seals**: These small, earless seals are found in tropical and subtropical waters around the world. They\'re endangered due to habitat loss and entanglement in fishing nets.\n6. **Otters**: Otters are playful, carnivorous mammals that live in coastal and estuarine environments. They\'re known for their sleek fur and ability to slide down rocks with ease.\n7. **Sirenians**: This group includes manatees, dugongs, and Steller\'s sea cows, which are large, herbivorous aquatic mammals that feed on sea grasses and other marine plants.\n8. **Pinnipeds**: This group includes seals, sea lions, and walruses, which are all fin-footed, carnivorous mammals that give birth to live young.\n9. **Porpoises**: Porpoises are small, toothed cetaceans that are related to dolphins and whales. They\'re shy and less social than dolphins, and are found in temperate and tropical waters.\n\nThese are just a few examples of the many amazing ocean mammals that exist. Each has its unique adaptations and characteristics, and they all play important roles in their ecosystems.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 411, 'prompt_tokens': 44, 'total_tokens': 455, 'completion_time': 0.3425, 'prompt_time': 0.005308069, 'queue_time': 0.018899148999999997, 'total_time': 0.347808069}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_179b0f92c9', 'finish_reason': 'stop', 'logprobs': None}, id='run-07ed2199-4cff-43d5-a724-2ad9c0209af0-0', usage_metadata={'input_tokens': 44, 'output_tokens': 411, 'total_tokens': 455})

# %% [markdown]
# We can run our chat model in a simple graph with `MessagesState`.

# %%
from IPython.display import Image, display
from langgraph.graph import MessagesState
from langgraph.graph import StateGraph, START, END

# Node
def chat_model_node(state: MessagesState):
    return {"messages": llm.invoke(state["messages"])}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# There are many fascinating ocean mammals beyond whales. Here are some you might find interesting:
#
# 1. **Dolphins**: These intelligent, social creatures are closely related to whales and are known for their playful behavior and distinctive clicks.
# 2. **Seals and Sea Lions**: These pinnipeds (fin-footed mammals) are found in oceans worldwide and are known for their agility and ability to haul out on land.
# 3. **Walruses**: With their distinctive tusks and blubbery bodies, walruses are a common sight in Arctic and sub-Arctic waters.
# 4. **Manatees**: Also known as sea cows, manatees are large, slow-moving aquatic mammals found in warm waters around the world.
# 5. **Monk Seals**: These tropical and subtropical seals are known for their distinctive V-shaped nostrils and are found in the Indo-Pacific and Atlantic Oceans.
# 6. **Otters**: There are several species of otters that live in or near the ocean, such as the sea otter, which is found in the Pacific Northwest and is known for its thick fur and ability to use tools.
# 7. **Sea Otters**: As mentioned above, sea otters are a type of otter that lives in the ocean and is known for its remarkable adaptability and unique behaviors.
# 8. **Belugas**: These small, white whales are found in the Arctic and sub-Arctic and are known for their distinctive coloration and ability to make a variety of sounds.
# 9. **Porpoises**: Porpoises are small toothed cetaceans that are often confused with dolphins, but are actually a distinct group. They are found in oceans worldwide.
# 10. **Dugongs**: These large marine mammals are found in warm waters in the Indo-Pacific and are related to manatees and elephants.
#
# These are just a few examples of the many fascinating ocean mammals that exist. Each has its own unique characteristics and adaptations that have evolved to help it thrive in its environment.

# %% [markdown]
# ## Reducer
#
# A practical challenge when working with messages is managing long-running conversations.
#
# Long-running conversations result in high token usage and latency if we are not careful, because we pass a growing list of messages to the model.
#
# We have a few ways to address this.
#
# First, recall the trick we saw using `RemoveMessage` and the `add_messages` reducer.

# %%
from langchain_core.messages import RemoveMessage

# Nodes
def filter_messages(state: MessagesState):
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"messages": delete_messages}

def chat_model_node(state: MessagesState):
    return {"messages": [llm.invoke(state["messages"])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("filter", filter_messages)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "filter")
builder.add_edge("filter", "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
# Message list with a preamble
messages = [AIMessage("Hi.", name="Bot", id="1")]
messages.append(HumanMessage("Hi.", name="Lance", id="2"))
messages.append(AIMessage("So you said you were researching ocean mammals?", name="Bot", id="3"))
messages.append(HumanMessage("Yes, I know about whales. But what others should I learn about?", name="Lance", id="4"))

# Invoke
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# There are many fascinating ocean mammals beyond whales. Here are a few you might find interesting:
#
# 1. **Dolphins**: These intelligent, social mammals are known for their playful behavior and ability to communicate with each other.
# 2. **Porpoises**: Similar to dolphins, but with a more robust body and a distinctive small triangular dorsal fin.
# 3. **Seals and Sea Lions**: These pinnipeds (fin-footed mammals) come in various species, like harbor seals, elephant seals, and California sea lions. They're found in oceans worldwide and are known for their agility and playful nature.
# 4. **Manatees**: Also known as "sea cows," these large, slow-moving aquatic mammals are found in shallow waters in the Caribbean and Gulf of Mexico.
# 5. **Walruses**: These massive, tusked mammals are found in Arctic and sub-Arctic waters, where they feed on clams and other marine animals.
# 6. **Monk Seals**: These ancient, eel-like mammals are found in tropical and subtropical waters, and are known for their unique ability to hunt and eat octopuses.
# 7. **Dugongs**: Similar to manatees, these large, herbivorous mammals are found in shallow waters in the Pacific and Indian Oceans.
# 8. **Belugas**: These small, white whales are found in Arctic and sub-Arctic waters, and are known for their distinctive whistles and social behavior.
#
# These are just a few examples of the many amazing ocean mammals that exist. Each one has its unique characteristics, adaptations, and habits, making them all worth learning about!

# %% [markdown]
# ## Filtering messages
#
# If you don't need or want to modify the graph state, you can just filter the messages you pass to the chat model.
#
# For example, just pass in a filtered list: `llm.invoke(messages[-1:])` to the model.

# %%
# Node
def chat_model_node(state: MessagesState):
    return {"messages": [llm.invoke(state["messages"][-1:])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# Let's take our existing list of messages, append the above LLM response, and append a follow-up question.

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me more about Narwhals!", name="Lance"))

# %%
for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# There are many fascinating ocean mammals beyond whales. Here are a few you might find interesting:
#
# 1. **Dolphins**: These intelligent, social mammals are known for their playful behavior and ability to communicate with each other.
# 2. **Porpoises**: Similar to dolphins, but with a more robust body and a distinctive small triangular dorsal fin.
# 3. **Seals and Sea Lions**: These pinnipeds (fin-footed mammals) come in various species, like harbor seals, elephant seals, and California sea lions. They're found in oceans worldwide and are known for their agility and playful nature.
# 4. **Manatees**: Also known as "sea cows," these large, slow-moving aquatic mammals are found in shallow waters in the Caribbean and Gulf of Mexico.
# 5. **Walruses**: These massive, tusked mammals are found in Arctic and sub-Arctic waters, where they feed on clams and other marine animals.
# 6. **Monk Seals**: These ancient, eel-like mammals are found in tropical and subtropical waters, and are known for their unique ability to hunt and eat octopuses.
# 7. **Dugongs**: Similar to manatees, these large, herbivorous mammals are found in shallow waters in the Pacific and Indian Oceans.
# 8. **Belugas**: These small, white whales are found in Arctic and sub-Arctic waters, and are known for their distinctive whistles and social behavior.
#
# These are just a few examples of the many amazing ocean mammals that exist. Each one has its unique characteristics, adaptations, and habits, making them all worth learning about!
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!

# %%
# Invoke, using message filtering
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# There are many fascinating ocean mammals beyond whales. Here are a few you might find interesting:
#
# 1. **Dolphins**: These intelligent, social mammals are known for their playful behavior and ability to communicate with each other.
# 2. **Porpoises**: Similar to dolphins, but with a more robust body and a distinctive small triangular dorsal fin.
# 3. **Seals and Sea Lions**: These pinnipeds (fin-footed mammals) come in various species, like harbor seals, elephant seals, and California sea lions. They're found in oceans worldwide and are known for their agility and playful nature.
# 4. **Manatees**: Also known as "sea cows," these large, slow-moving aquatic mammals are found in shallow waters in the Caribbean and Gulf of Mexico.
# 5. **Walruses**: These massive, tusked mammals are found in Arctic and sub-Arctic waters, where they feed on clams and other marine animals.
# 6. **Monk Seals**: These ancient, eel-like mammals are found in tropical and subtropical waters, and are known for their unique ability to hunt and eat octopuses.
# 7. **Dugongs**: Similar to manatees, these large, herbivorous mammals are found in shallow waters in the Pacific and Indian Oceans.
# 8. **Belugas**: These small, white whales are found in Arctic and sub-Arctic waters, and are known for their distinctive whistles and social behavior.
#
# These are just a few examples of the many amazing ocean mammals that exist. Each one has its unique characteristics, adaptations, and habits, making them all worth learning about!
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!
# ================================== Ai Message ==================================
#
# Narwhals! Those magnificent, mystical creatures of the Arctic!
#
# Also known as the "unicorns of the sea," narwhals (Monodon monoceros) are a species of whale with a unique feature that has captured the imagination of humans for centuries: their spiraling, horn-like tusk.
#
# Here are some fascinating facts about narwhals:
#
# **The Tusk:** Narwhals are born without tusks, which start growing in when they're around 5-7 years old. The tusk, which is actually a modified tooth, can grow up to 10 feet (3 meters) long and is found only in males. It's made of ivory and is incredibly sensitive, with thousands of nerve endings. Scientists believe the tusk might be used for sensing the environment, attracting mates, or even breaking through ice.
#
# **Appearance:** Narwhals have a bluish-gray back and white belly. They have a distinctive rounded head, a small dorsal fin, and a long, slender body that's up to 16 feet (4.9 meters) long. They weigh around 3,500-4,000 pounds (1,590-1,810 kilograms).
#
# **Habitat:** Narwhals live in the Arctic waters of Canada, Greenland, and Russia. They inhabit areas with dense sea ice and are found in shallow waters, often near the coast.
#
# **Diet:** Narwhals are carnivores and feed on Arctic cod, shrimp, and other marine animals. They're skilled hunters and can dive to depths of up to 5,000 feet (1,524 meters) in search of food.
#
# **Behavior:** Narwhals are social creatures and often swim in groups of up to 10 individuals. They're known for their curious nature and have been observed playing with each other's tusks.
#
# **Conservation Status:** Narwhals are listed as "near threatened" on the IUCN Red List due to threats from climate change, which is melting their sea ice habitat and affecting their food supply. They're also vulnerable to hunting and noise pollution from human activities.
#
# **Ancient Legends:** Narwhals have been a source of fascination for centuries. In medieval times, their tusks were believed to be a sign of the unicorn, and they were often used as a symbol of wealth and power.
#
# **Fascinating Fun Facts:**
#
# * Narwhals can live up to 50 years in the wild.
# * They're able to make a variety of sounds, including clicks, whistles, and grunts.
# * Narwhals have a unique way of swimming, using their tail to propel themselves through the water.
# * Inuit people have hunted narwhals for centuries, using their tusks to create decorative objects and jewelry.
#
# These incredible creatures continue to captivate us with their unique appearance and fascinating behaviors. Let's do our part to protect and conserve narwhals and their Arctic habitat for future generations!

# %% [markdown]
# The state has all of the mesages.
#
# But, let's look at the LangSmith trace to see that the model invocation only uses the last message:
#
# https://smith.langchain.com/public/75aca3ce-ef19-4b92-94be-0178c7a660d9/r

# %% [markdown]
# ## Trim messages
#
# Another approach is to [trim messages](https://python.langchain.com/v0.2/docs/how_to/trim_messages/#getting-the-last-max_tokens-tokens), based upon a set number of tokens.
#
# This restricts the message history to a specified number of tokens.
#
# While filtering only returns a post-hoc subset of the messages between agents, trimming restricts the number of tokens that a chat model can use to respond.
#
# See the `trim_messages` below.

# %%
from langchain_core.messages import trim_messages

# Node
def chat_model_node(state: MessagesState):
    messages = trim_messages(
            state["messages"],
            max_tokens=100,
            strategy="last",
            token_counter=ChatGroq(model="llama3-8b-8192"),
            allow_partial=False,
        )
    return {"messages": [llm.invoke(messages)]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me where Orcas live!", name="Lance"))

# %%
# Example of trimming messages
trim_messages(
            messages,
            max_tokens=100,
            strategy="last",
            token_counter=ChatGroq(model="llama3-8b-8192"),
            allow_partial=False
        )
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# [HumanMessage(content='Tell me where Orcas live!', additional_kwargs={}, response_metadata={}, name='Lance')]

# %%
# Invoke, using message trimming in the chat_model_node
messages_out_trim = graph.invoke({'messages': messages})
messages_out_trim
# Out:
# {'messages': [AIMessage(content='Hi.', additional_kwargs={}, response_metadata={}, name='Bot', id='1'),
#   HumanMessage(content='Hi.', additional_kwargs={}, response_metadata={}, name='Lance', id='2'),
#   AIMessage(content='So you said you were researching ocean mammals?', additional_kwargs={}, response_metadata={}, name='Bot', id='3'),
#   HumanMessage(content='Yes, I know about whales. But what others should I learn about?', additional_kwargs={}, response_metadata={}, name='Lance', id='4'),
#   AIMessage(content='There are many fascinating ocean mammals beyond whales. Here are a few you might find interesting:\n\n1. **Dolphins**: These intelligent, social mammals are known for their playful behavior and ability to communicate with each other.\n2. **Porpoises**: Similar to dolphins, but with a more robust body and a distinctive small triangular dorsal fin.\n3. **Seals and Sea Lions**: These pinnipeds (fin-footed mammals) come in various species, like harbor seals, elephant seals, and California sea lions. They\'re found in oceans worldwide and are known for their agility and playful nature.\n4. **Manatees**: Also known as "sea cows," these large, slow-moving aquatic mammals are found in shallow waters in the Caribbean and Gulf of Mexico.\n5. **Walruses**: These massive, tusked mammals are found in Arctic and sub-Arctic waters, where they feed on clams and other marine animals.\n6. **Monk Seals**: These ancient, eel-like mammals are found in tropical and subtropical waters, and are known for their unique ability to hunt and eat octopuses.\n7. **Dugongs**: Similar to manatees, these large, herbivorous mammals are found in shallow waters in the Pacific and Indian Oceans.\n8. **Belugas**: These small, white whales are found in Arctic and sub-Arctic waters, and are known for their distinctive whistles and social behavior.\n\nThese are just a few examples of the many amazing ocean mammals that exist. Each one has its unique characteristics, adaptations, and habits, making them all worth learning about!', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 333, 'prompt_tokens': 44, 'total_tokens': 377, 'completion_time': 0.2775, 'prompt_time': 0.008104048, 'queue_time': 0.018328192, 'total_time': 0.285604048}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'stop', 'logprobs': None}, id='run-d644b772-78bd-42df-b5ef-f4410ff705e4-0', usage_metadata={'input_tokens': 44, 'output_tokens': 333, 'total_tokens': 377}),
#   HumanMessage(content='Tell me more about Narwhals!', additional_kwargs={}, response_metadata={}, name='Lance', id='de41884d-7e21-4602-9c9f-5818699c7180'),
#   AIMessage(content='Narwhals! Those magnificent, mystical creatures of the Arctic!\n\nAlso known as the "unicorns of the sea," narwhals (Monodon monoceros) are a species of whale with a unique feature that has captured the imagination of humans for centuries: their spiraling, horn-like tusk.\n\nHere are some fascinating facts about narwhals:\n\n**The Tusk:** Narwhals are born without tusks, which start growing in when they\'re around 5-7 years old. The tusk, which is actually a modified tooth, can grow up to 10 feet (3 meters) long and is found only in males. It\'s made of ivory and is incredibly sensitive, with thousands of nerve endings. Scientists believe the tusk might be used for sensing the environment, attracting mates, or even breaking through ice.\n\n**Appearance:** Narwhals have a bluish-gray back and white belly. They have a distinctive rounded head, a small dorsal fin, and a long, slender body that\'s up to 16 feet (4.9 meters) long. They weigh around 3,500-4,000 pounds (1,590-1,810 kilograms).\n\n**Habitat:** Narwhals live in the Arctic waters of Canada, Greenland, and Russia. They inhabit areas with dense sea ice and are found in shallow waters, often near the coast.\n\n**Diet:** Narwhals are carnivores and feed on Arctic cod, shrimp, and other marine animals. They\'re skilled hunters and can dive to depths of up to 5,000 feet (1,524 meters) in search of food.\n\n**Behavior:** Narwhals are social creatures and often swim in groups of up to 10 individuals. They\'re known for their curious nature and have been observed playing with each other\'s tusks.\n\n**Conservation Status:** Narwhals are listed as "near threatened" on the IUCN Red List due to threats from climate change, which is melting their sea ice habitat and affecting their food supply. They\'re also vulnerable to hunting and noise pollution from human activities.\n\n**Ancient Legends:** Narwhals have been a source of fascination for centuries. In medieval times, their tusks were believed to be a sign of the unicorn, and they were often used as a symbol of wealth and power.\n\n**Fascinating Fun Facts:**\n\n* Narwhals can live up to 50 years in the wild.\n* They\'re able to make a variety of sounds, including clicks, whistles, and grunts.\n* Narwhals have a unique way of swimming, using their tail to propel themselves through the water.\n* Inuit people have hunted narwhals for centuries, using their tusks to create decorative objects and jewelry.\n\nThese incredible creatures continue to captivate us with their unique appearance and fascinating behaviors. Let\'s do our part to protect and conserve narwhals and their Arctic habitat for future generations!', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 598, 'prompt_tokens': 18, 'total_tokens': 616, 'completion_time': 0.498333333, 'prompt_time': 0.002372471, 'queue_time': 0.018617439, 'total_time': 0.500705804}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_179b0f92c9', 'finish_reason': 'stop', 'logprobs': None}, id='run-b5ab5535-936e-45f4-ac94-a4ed901c30a6-0', usage_metadata={'input_tokens': 18, 'output_tokens': 598, 'total_tokens': 616}),
#   HumanMessage(content='Tell me where Orcas live!', additional_kwargs={}, response_metadata={}, name='Lance', id='acb3cb65-6e27-4afc-8c95-877ecc92eda3'),
#   AIMessage(content="Orcas, also known as killer whales, are found in all the world's oceans, from the Arctic to the Antarctic, and in every ocean in between. They are a highly adaptable species and can be found in both warm and cold waters, as well as in coastal areas and open ocean.\n\nSome specific locations where orcas can be found include:\n\n* The Pacific Ocean: Orcas are abundant in the Pacific Ocean, particularly in the waters around Japan, Russia, and the west coast of North America.\n* The Atlantic Ocean: Orcas can be found in the Atlantic Ocean, particularly in the waters around Europe, Africa, and the eastern coast of North America.\n* The Indian Ocean: Orcas are found in the Indian Ocean, particularly in the waters around India, Africa, and Southeast Asia.\n* The Arctic Ocean: Orcas can be found in the Arctic Ocean, particularly in the waters around Alaska, Canada, and Russia.\n* The Antarctic Ocean: Orcas are found in the Antarctic Ocean, particularly in the waters around Antarctica and the surrounding islands.\n\nSome specific locations where orcas are known to frequent include:\n\n* The Salish Sea: Orcas are common in the Salish Sea, which is located between the states of Washington and British Columbia, Canada.\n* Puget Sound: Orcas can be found in Puget Sound, which is located in the state of Washington, USA.\n* Monterey Bay: Orcas can be found in Monterey Bay, which is located on the coast of California, USA.\n* The Gulf of Alaska: Orcas are common in the Gulf of Alaska, which is located in the state of Alaska, USA.\n* The waters around Hawaii: Orcas can be found in the waters around the state of Hawaii, USA.\n\nIt's worth noting that orcas are highly migratory animals, so they can be found in many different locations throughout the year.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 381, 'prompt_tokens': 17, 'total_tokens': 398, 'completion_time': 0.3175, 'prompt_time': 0.002475921, 'queue_time': 0.018064408, 'total_time': 0.319975921}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'stop', 'logprobs': None}, id='run-8bce78e1-6dde-448b-a9b4-1dc0c75f83bc-0', usage_metadata={'input_tokens': 17, 'output_tokens': 381, 'total_tokens': 398})]}

# %% [markdown]
# Let's look at the LangSmith trace to see the model invocation:
#
# https://smith.langchain.com/public/b153f7e9-f1a5-4d60-8074-f0d7ab5b42ef/r
